# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

mpl.rcParams['figure.figsize'] = (12, 10)

results = pd.read_csv('../data/all_accuracy_results.csv', delimiter=',', encoding="utf-8-sig", header=0)
results['Network'] = pd.Series([ results['Network'].loc[idx].replace('_no_weight_dependence', '') \
                                                                for idx in xrange(len(results)) ])
results['Network'] = pd.Series([ results['Network'].loc[idx].replace('_weight_dependence', '') \
                                                                for idx in xrange(len(results)) ])
results['Network'] = pd.Series([ results['Network'].loc[idx].replace('_no_postpre', '') \
                                                                for idx in xrange(len(results)) ])
results['Network'] = pd.Series([ results['Network'].loc[idx].replace('_postpre', '') \
                                                                for idx in xrange(len(results)) ])
results['Network'] = pd.Series([ results['Network'].loc[idx].replace('no_weight_sharing', 'NWS') \
                                                                for idx in xrange(len(results)) ])
results['Network'] = pd.Series([ results['Network'].loc[idx].replace('weight_sharing', 'WS') \
                                                                for idx in xrange(len(results)) ])
results['Network'] = pd.Series([ ' '.join(results['Network'].loc[idx].split('_')[2:-1]) \
                                                                for idx in xrange(len(results)) ])

results.sort_values(['All'], ascending=False)
# Out:
#                      Network    All  Most-spiked per patch  \
# 36    none 16 4 100 16 NWS 4  87.65                  87.17
# 66   pairs 16 4 100 16 NWS 4  87.20                  86.61
# 113   none 12 4 100 25 NWS 4  86.68                  84.82
# 99    pairs 14 2 50 64 NWS 4  84.32                  83.17
# 108    none 14 2 50 64 NWS 8  84.21                  82.82
# 37    pairs 14 2 50 64 NWS 8  84.18                  83.19
# 71     none 14 2 50 64 NWS 8  84.18                  82.86
# 49     none 14 2 50 64 NWS 4  83.94                  82.39
# 46     none 12 2 50 81 NWS 8  83.56                  81.18
# 104   pairs 14 2 50 64 NWS 8  83.37                  82.02
# 100   pairs 12 2 50 81 NWS 8  83.31                  81.31
# 26   pairs 10 2 50 100 NWS 8  82.95                  79.44
# 41    none 10 2 50 100 NWS 8  82.58                  79.68
# 91     none 12 4 50 25 NWS 4  82.02                  78.59
# 21    pairs 12 4 50 25 NWS 4  81.28                  78.16
# 79      all 12 2 50 81 NWS 8  80.85                  77.99
# 19    pairs 8 2 50 121 NWS 8  80.79                  77.21
# 98      all 14 2 50 64 NWS 8  80.50                  80.01
# 89     none 16 4 50 16 NWS 4  80.43                  79.79
# 111    none 8 2 50 121 NWS 8  80.21                  76.69
# 52     none 16 2 50 49 NWS 8  80.02                  79.39
# 8     pairs 16 4 50 16 NWS 4  80.00                  78.68
# 40     all 10 2 50 100 NWS 8  79.75                  76.42
# 3       all 12 4 50 25 NWS 4  79.52                  76.72
# 76    pairs 16 2 50 49 NWS 8  79.48                  78.88
# 31      all 16 4 50 16 NWS 4  79.23                  78.00
# 114    none 18 2 50 36 NWS 8  78.93                  78.76
# 24    pairs 18 2 50 36 NWS 8  78.89                  78.77
# 0       none 8 4 50 36 NWS 4  76.94                  72.73
# 42      all 16 2 50 49 NWS 8  76.62                  76.12
# ..                       ...    ...                    ...
# 109   pairs 10 2 50 100 WS 8  62.92                  63.86
# 102     all 12 4 100 25 WS 4  62.58                  71.97
# 97     none 12 4 100 25 WS 4  62.02                  67.30
# 6        all 12 4 50 25 WS 4  61.38                  64.36
# 106    none 16 4 100 16 WS 4  61.29                  71.74
# 33      none 20 2 50 25 WS 8  61.00                  68.28
# 1      pairs 27 1 50 4 NWS 8  60.99                  61.68
# 12     pairs 20 2 50 25 WS 8  60.73                  68.87
# 4        all 14 2 50 64 WS 8  60.63                  68.45
# 78     pairs 16 2 50 49 WS 8  60.01                  67.35
# 62      none 16 2 50 49 WS 8  59.27                  66.36
# 72       all 27 1 50 4 NWS 8  59.15                  58.83
# 96       none 27 1 50 4 WS 8  59.06                  60.01
# 101      all 8 2 50 121 WS 8  58.71                  60.81
# 17     pairs 8 2 50 121 WS 8  58.63                  60.21
# 18       all 18 2 50 36 WS 8  57.98                  64.53
# 110      all 20 2 50 25 WS 8  57.97                  63.51
# 55       all 16 2 50 49 WS 8  57.52                  66.04
# 105      none 8 4 50 36 WS 4  57.35                  58.71
# 27     pairs 18 2 50 36 WS 8  57.21                  66.19
# 23     none 10 6 100 16 WS 4  56.61                  57.52
# 94       all 16 4 50 16 WS 4  56.35                  67.66
# 65       all 18 2 50 36 WS 4  56.31                  68.12
# 75      none 18 2 50 36 WS 8  56.15                  66.35
# 45      all 10 6 100 16 WS 4  56.02                  59.78
# 47      pairs 27 1 50 4 WS 8  54.34                  58.47
# 107     none 16 4 50 16 WS 4  53.52                  65.78
# 63        all 27 1 50 4 WS 8  53.06                  56.42
# 85        all 8 4 50 36 WS 4  51.67                  51.76
# 95      none 10 6 50 16 WS 4  46.37                  47.48
#
#      Most-spiked overall  Correlation clustering
# 36                 86.19                   85.89
# 66                 85.72                   85.72
# 113                83.49                   85.96
# 99                 82.32                   80.31
# 108                82.05                   81.82
# 37                 82.02                   81.17
# 71                 82.04                   80.83
# 49                 81.76                   81.33
# 46                 80.50                   81.20
# 104                81.10                   80.74
# 100                80.56                   80.58
# 26                 78.39                   80.37
# 41                 78.16                   80.03
# 91                 78.00                   79.08
# 21                 77.73                   80.35
# 79                 77.46                   76.10
# 19                 75.22                   79.24
# 98                 78.61                   76.09
# 89                 77.64                   79.35
# 111                73.83                   79.57
# 52                 76.82                   78.75
# 8                  77.79                   78.73
# 40                 74.11                   75.70
# 3                  76.35                   78.26
# 76                 76.37                   77.86
# 31                 75.74                   77.28
# 114                76.41                   77.30
# 24                 76.33                   77.66
# 0                  70.51                   78.71
# 42                 73.64                   75.52
# ..                   ...                     ...
# 109                68.33                   41.67
# 102                74.89                   71.03
# 97                 72.96                   70.03
# 6                  68.58                   67.93
# 106                71.78                   75.37
# 33                 70.22                   69.03
# 1                  60.41                   60.47
# 12                 68.66                   67.04
# 4                  72.20                   64.05
# 78                 67.32                   59.91
# 62                 67.76                   62.69
# 72                 57.98                   57.45
# 96                 61.70                   62.94
# 101                64.78                   48.85
# 17                 65.66                   37.56
# 18                 68.72                   64.74
# 110                66.24                   68.81
# 55                 66.08                   60.39
# 105                68.64                   66.85
# 27                 69.85                   63.35
# 23                 65.32                   73.81
# 94                 69.60                   72.40
# 65                 70.38                   66.27
# 75                 67.40                   63.49
# 45                 66.58                   74.78
# 47                 58.38                   58.06
# 107                66.85                   69.86
# 63                 55.02                   57.22
# 85                 61.59                   61.08
# 95                 54.18                   54.80
#
# [115 rows x 5 columns]

# %%
results['Connectivity'] = pd.Series([ results['Network'].loc[idx].split(' ')[0] for idx in xrange(len(results)) ])
results['Convolution Size'] = pd.Series([ int(results['Network'].loc[idx].split(' ')[1]) for idx in xrange(len(results)) ])
results['Stride'] = pd.Series([ int(results['Network'].loc[idx].split(' ')[2]) for idx in xrange(len(results)) ])
results['No. Patches'] = pd.Series([ int(results['Network'].loc[idx].split(' ')[3]) for idx in xrange(len(results)) ])
results['Weight Sharing'] = pd.Series([ results['Network'].loc[idx].split(' ')[5] for idx in xrange(len(results)) ])
results['Lattice Structure'] = pd.Series([ int(results['Network'].loc[idx].split(' ')[6]) for idx in xrange(len(results)) ])

results = results.drop('Network', 1)

results = results.sort_values(['Connectivity', 'Convolution Size', 'Stride'])
results = results.set_index(['Connectivity', 'Convolution Size', 'Stride'])

# %%
sub_tables = {}
for lattice_structure in [4, 8]:
    for weight_sharing in ['WS', 'NWS']:
        for n_patches in [50, 100]:
            sub_table = results.loc[(results['Weight Sharing'] == weight_sharing) & \
                (results['Lattice Structure'] == lattice_structure) & \
                (results['No. Patches'] == n_patches)].drop(['Lattice Structure', \
                                    'Weight Sharing', 'No. Patches'], 1)
            sub_tables[(lattice_structure, weight_sharing, n_patches)] = sub_table

# %%
sub_tables[0]
# Out:
#                                         All  Most-spiked per patch  \
# Connectivity Convolution Size Stride
# all          8                4       51.67                  51.76
#              12               4       61.38                  64.36
#              14               2       65.48                  69.47
#              16               4       56.35                  67.66
#              18               2       56.31                  68.12
# none         8                4       57.35                  58.71
#              10               6       46.37                  47.48
#              12               4       63.09                  58.25
#              16               4       53.52                  65.78
#              26               1       63.72                  63.37
#
#                                       Most-spiked overall  \
# Connectivity Convolution Size Stride
# all          8                4                     61.59
#              12               4                     68.58
#              14               2                     70.49
#              16               4                     69.60
#              18               2                     70.38
# none         8                4                     68.64
#              10               6                     54.18
#              12               4                     62.68
#              16               4                     66.85
#              26               1                     65.97
#
#                                       Correlation clustering
# Connectivity Convolution Size Stride
# all          8                4                        61.08
#              12               4                        67.93
#              14               2                        64.01
#              16               4                        72.40
#              18               2                        66.27
# none         8                4                        66.85
#              10               6                        54.80
#              12               4                        70.86
#              16               4                        69.86
#              26               1                        60.09

# %%
sub_tables[1]
# Out:
#                                         All  Most-spiked per patch  \
# Connectivity Convolution Size Stride
# all          10               6       56.02                  59.78
#              12               4       63.13                  69.00
#                               4       62.58                  71.97
#              16               4       65.78                  71.97
#              27               1       74.00                  74.05
# none         10               6       56.61                  57.52
#              12               4       62.02                  67.30
#              16               4       61.29                  71.74
#              27               1       71.93                  71.10
#
#                                       Most-spiked overall  \
# Connectivity Convolution Size Stride
# all          10               6                     66.58
#              12               4                     71.86
#                               4                     74.89
#              16               4                     74.18
#              27               1                     72.70
# none         10               6                     65.32
#              12               4                     72.96
#              16               4                     71.78
#              27               1                     70.73
#
#                                       Correlation clustering
# Connectivity Convolution Size Stride
# all          10               6                        74.78
#              12               4                        71.69
#                               4                        71.03
#              16               4                        74.77
#              27               1                        69.33
# none         10               6                        73.81
#              12               4                        70.03
#              16               4                        75.37
#              27               1                        68.98

# %%
sub_tables[2]
# Out:
#                                         All  Most-spiked per patch  \
# Connectivity Convolution Size Stride
# all          8                4       75.59                  72.65
#                               4       75.84                  72.87
#              10               6       74.77                  70.88
#              12               4       79.52                  76.72
#              16               4       79.23                  78.00
#              26               1       65.77                  64.83
#              27               1       64.06                  65.08
# none         8                4       76.94                  72.73
#                               4       75.76                  72.83
#              10               6       74.95                  71.57
#              12               4       82.02                  78.59
#              14               2       83.94                  82.39
#              16               4       80.43                  79.79
#              26               1       68.79                  67.86
#              27               1       65.08                  64.87
# pairs        8                4       76.29                  72.27
#                               4       76.59                  72.92
#              10               6       74.57                  71.51
#              12               4       81.28                  78.16
#              14               2       84.32                  83.17
#              16               4       80.00                  78.68
#              26               1       69.63                  69.45
#              27               1       63.62                  63.57
#
#                                       Most-spiked overall  \
# Connectivity Convolution Size Stride
# all          8                4                     69.67
#                               4                     70.58
#              10               6                     69.81
#              12               4                     76.35
#              16               4                     75.74
#              26               1                     64.13
#              27               1                     63.42
# none         8                4                     70.51
#                               4                     70.19
#              10               6                     69.91
#              12               4                     78.00
#              14               2                     81.76
#              16               4                     77.64
#              26               1                     65.95
#              27               1                     64.26
# pairs        8                4                     70.00
#                               4                     70.67
#              10               6                     70.36
#              12               4                     77.73
#              14               2                     82.32
#              16               4                     77.79
#              26               1                     68.48
#              27               1                     62.93
#
#                                       Correlation clustering
# Connectivity Convolution Size Stride
# all          8                4                        77.21
#                               4                        77.79
#              10               6                        74.12
#              12               4                        78.26
#              16               4                        77.28
#              26               1                        63.00
#              27               1                        65.59
# none         8                4                        78.71
#                               4                        78.22
#              10               6                        75.46
#              12               4                        79.08
#              14               2                        81.33
#              16               4                        79.35
#              26               1                        66.15
#              27               1                        61.90
# pairs        8                4                        79.28
#                               4                        78.26
#              10               6                        74.52
#              12               4                        80.35
#              14               2                        80.31
#              16               4                        78.73
#              26               1                        67.07
#              27               1                        62.94
